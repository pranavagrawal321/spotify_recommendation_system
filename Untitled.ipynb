# %%
# !pip install kaggle pandas

# %%
# !kaggle datasets download -d yamaerenay/spotify-dataset-19212020-600k-tracks
# Out:
# Dataset URL: https://www.kaggle.com/datasets/yamaerenay/spotify-dataset-19212020-600k-tracks
# License(s): Community Data License Agreement - Sharing - Version 1.0
# ...
# 100%|████████████████████████████████████████| 193M/193M [00:25<00:00, 10.2MB/s]
# 100%|████████████████████████████████████████| 193M/193M [00:25<00:00, 7.99MB/s]

# %%
# !unzip spotify-dataset-19212020-600k-tracks.zip -d dataset
# Out:
# Archive:  spotify-dataset-19212020-600k-tracks.zip
#   inflating: dataset/artists.csv
#   inflating: dataset/dict_artists.json
#   inflating: dataset/tracks.csv

# %%
ls dataset/
# Out:
# artists.csv  dict_artists.json  tracks.csv

# %%
import pandas as pd

# %%
artists = pd.read_csv('dataset/artists.csv')

# %%
artists.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
artists.rename(columns={
    'id': 'id_artists',
    'followers': 'artist_followers',
    'name': 'artists',
    'popularity': 'artist_popularity',
    'genres': 'genre'
}, inplace=True)

# %%
artists.head()
# Out:
#                id_artists  artist_followers genre  \
# 0  0DheY5irMjBUeLybbCUEZ2               0.0    []
# 1  0DlhY15l3wsrnlfGio2bjU               5.0    []
# 2  0DmRESX2JknGPQyO15yxg7               0.0    []
# 3  0DmhnbHjm1qw6NCYPeZNgJ               0.0    []
# 4  0Dn11fWM7vHQ3rinvWEl4E               2.0    []
#
#                                           artists  artist_popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani                  0
# 1                                     ปูนา ภาวิณี                  0
# 2                                           Sadaa                  0
# 3                                       Tra'gruda                  0
# 4                          Ioannis Panoutsopoulos                  0

# %%
tracks = pd.read_csv('dataset/tracks.csv')

# %%
tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
tracks.shape
# Out:
# (586672, 20)

# %%
tracks['id_artists'][586670]
# Out:
# "['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2gkqjn']"

# %%
eval(tracks['id_artists'][586670])
# Out:
# ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2gkqjn']

# %%
tracks['id_artists'] = tracks['id_artists'].apply(eval)

# %%
tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                id_artists  \
# 0       126903         0              ['Uli']  [45tIt06XoI0Iio4LBEVpls]
# 1        98200         0  ['Fernando Pessoa']  [14jtPCOoNZwquk5wd9DxrY]
# 2       181640         0  ['Ignacio Corsini']  [5LiOoJbxVSAMkBS2fUm3X2]
# 3       176907         0  ['Ignacio Corsini']  [5LiOoJbxVSAMkBS2fUm3X2]
# 4       163080         0      ['Dick Haymes']  [3BiJGZsyX9sJchTqcSA7Su]
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
tracks['id_artists'][0]
# Out:
# ['45tIt06XoI0Iio4LBEVpls']

# %%
tracks['artists'][0]
# Out:
# "['Uli']"

# %%
tracks['artists'] = tracks['artists'].apply(eval)

# %%
tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit            artists                id_artists  \
# 0       126903         0              [Uli]  [45tIt06XoI0Iio4LBEVpls]
# 1        98200         0  [Fernando Pessoa]  [14jtPCOoNZwquk5wd9DxrY]
# 2       181640         0  [Ignacio Corsini]  [5LiOoJbxVSAMkBS2fUm3X2]
# 3       176907         0  [Ignacio Corsini]  [5LiOoJbxVSAMkBS2fUm3X2]
# 4       163080         0      [Dick Haymes]  [3BiJGZsyX9sJchTqcSA7Su]
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
tracks.tail()
# Out:
#                             id                       name  popularity  \
# 586667  5rgu12WBIHQtvej2MdHSH0                        云与海          50
# 586668  0NuWgxEp51CutD2pJoF4OM                      blind          72
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 586670  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn           Mar de Emociones          38
#
#         duration_ms  explicit                      artists  \
# 586667       258267         0                    [阿YueYue]
# 586668       153293         0                 [ROLE MODEL]
# 586669       187601         0                    [FINNEAS]
# 586670       142003         0  [Gentle Bones, Clara Benin]
# 586671       214360         0                  [Afrosound]
#
#                                               id_artists release_date  \
# 586667                          [1QLBXKM5GCpyQQSVMNZqrZ]   2020-09-26
# ...

# %%
tracks.shape
# Out:
# (586672, 20)

# %%
tracks = tracks.explode(['artists', 'id_artists'])

# %%
tracks.tail()
# Out:
#                             id                       name  popularity  \
# 586668  0NuWgxEp51CutD2pJoF4OM                      blind          72
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 586670  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 586670  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn           Mar de Emociones          38
#
#         duration_ms  explicit       artists              id_artists  \
# 586668       153293         0    ROLE MODEL  1dy5WNgIKQU6ezkpZs4y8z
# 586669       187601         0       FINNEAS  37M5pPGs6V1fchFJSgCguX
# 586670       142003         0  Gentle Bones  4jGPdu95icCKVF31CcFKbS
# 586670       142003         0   Clara Benin  5ebPSE9YI5aLeZ1Z2gkqjn
# 586671       214360         0     Afrosound  0i4Qda0k4nf7jnNHmSNpYv
#
#        release_date  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
tracks.reset_index(drop=True, inplace=True)

# %%
tracks.tail()
# Out:
#                             id                       name  popularity  \
# 757165  0NuWgxEp51CutD2pJoF4OM                      blind          72
# 757166  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 757167  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 757168  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 757169  5Ocn6dZ3BJFPWh4ylwFXtn           Mar de Emociones          38
#
#         duration_ms  explicit       artists              id_artists  \
# 757165       153293         0    ROLE MODEL  1dy5WNgIKQU6ezkpZs4y8z
# 757166       187601         0       FINNEAS  37M5pPGs6V1fchFJSgCguX
# 757167       142003         0  Gentle Bones  4jGPdu95icCKVF31CcFKbS
# 757168       142003         0   Clara Benin  5ebPSE9YI5aLeZ1Z2gkqjn
# 757169       214360         0     Afrosound  0i4Qda0k4nf7jnNHmSNpYv
#
#        release_date  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
data = tracks.merge(artists)

# %%
data.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit          artists              id_artists  \
# 0       126903         0              Uli  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  Fernando Pessoa  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  ...  speechiness  acousticness  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'artist_followers',
#        'genre', 'artist_popularity'],
#       dtype='object')

# %%
data['release_date'][0]
# Out:
# '1922-02-22'

# %%
data['release_date'] = data['release_date'].astype('datetime64[ns]')

# %%
data.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit          artists              id_artists  \
# 0       126903         0              Uli  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  Fernando Pessoa  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  ...  speechiness  acousticness  \
# ...

# %%
data['release_date'][0]
# Out:
# Timestamp('1922-02-22 00:00:00')

# %%
data['year'] = data['release_date'].dt.strftime("%Y")

# %%
data.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit          artists              id_artists  \
# 0       126903         0              Uli  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  Fernando Pessoa  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  ...  acousticness  instrumentalness  \
# ...

# %%
data['year']
# Out:
# 0         1922
# 1         1922
# 2         1922
# 3         1922
# 4         1922
#           ...
# 730939    2020
# 730940    2020
# 730941    2021
# 730942    2021
# 730943    2015
# Name: year, Length: 730944, dtype: object

# %%
data['popularity'].describe()
# Out:
# count    730944.000000
# mean         26.917786
# std          19.120181
# min           0.000000
# 25%          10.000000
# 50%          26.000000
# 75%          41.000000
# max         100.000000
# Name: popularity, dtype: float64

# %%
import re

# %%
data['genre'] = data['genre'].apply(lambda x: [re.sub(' ','_',i) for i in re.findall(r"'([^']*)'", x)])

# %%
data.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit          artists              id_artists  \
# 0       126903         0              Uli  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  Fernando Pessoa  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  ...  acousticness  instrumentalness  \
# ...

# %%
data[['id', 'genre']].tail()
# Out:
#                             id  \
# 730939  0NuWgxEp51CutD2pJoF4OM
# 730940  27Y1N4Q4U3EfDU5Ubw8ws2
# 730941  45XJsGpFTyzbzeWK8VzR8S
# 730942  45XJsGpFTyzbzeWK8VzR8S
# 730943  5Ocn6dZ3BJFPWh4ylwFXtn
#
#                                                     genre
# 730939  [alt_z, alternative_r&b, bedroom_pop, indie_ca...
# 730940  [alt_z, electropop, indie_pop, la_indie, pop, ...
# 730941       [chill_r&b, indie_cafe_pop, singaporean_pop]
# 730942        [opm, pinoy_indie, pinoy_singer-songwriter]
# 730943                        [chicha, cumbia, nu-cumbia]

# %%
merged_genre = data.groupby('id')['genre'].sum()

# %%
merged_genre.head()
# Out:
# id
# 0004Uy71ku11n3LMpuyf59                                        [polish_rock]
# 000CSYu4rvd8cQ7JilfxhZ                  [country_quebecois, rock_quebecois]
# 000DsoWJKHdaUmhgcnpr8j                                          [barnmusik]
# 000G1xMMuwxNHmwVsBdtj1    [candy_pop, new_wave, new_wave_pop, permanent_...
# 000KblXP5csWFFFsD6smOy      [chamame, folclore_salteno, folklore_argentino]
# Name: genre, dtype: object

# %%
data.drop(columns='genre', inplace=True)

# %%
data = data.merge(merged_genre, on='id', how='left')

# %%
data.tail()
# Out:
#                             id                       name  popularity  \
# 730939  0NuWgxEp51CutD2pJoF4OM                      blind          72
# 730940  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 730941  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 730942  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 730943  5Ocn6dZ3BJFPWh4ylwFXtn           Mar de Emociones          38
#
#         duration_ms  explicit       artists              id_artists  \
# 730939       153293         0    ROLE MODEL  1dy5WNgIKQU6ezkpZs4y8z
# 730940       187601         0       FINNEAS  37M5pPGs6V1fchFJSgCguX
# 730941       142003         0  Gentle Bones  4jGPdu95icCKVF31CcFKbS
# 730942       142003         0   Clara Benin  5ebPSE9YI5aLeZ1Z2gkqjn
# 730943       214360         0     Afrosound  0i4Qda0k4nf7jnNHmSNpYv
#
#        release_date  danceability  energy  ...  acousticness  \
# 730939   2020-10-21         0.765   0.663  ...         0.141
# ...

# %%
data[data['id'] == '45XJsGpFTyzbzeWK8VzR8S']
# Out:
#                             id             name  popularity  duration_ms  \
# 730941  45XJsGpFTyzbzeWK8VzR8S  A Day At A Time          58       142003
# 730942  45XJsGpFTyzbzeWK8VzR8S  A Day At A Time          58       142003
#
#         explicit       artists              id_artists release_date  \
# 730941         0  Gentle Bones  4jGPdu95icCKVF31CcFKbS   2021-03-05
# 730942         0   Clara Benin  5ebPSE9YI5aLeZ1Z2gkqjn   2021-03-05
#
#         danceability  energy  ...  acousticness  instrumentalness  liveness  \
# 730941         0.696   0.615  ...         0.206          0.000003     0.305
# 730942         0.696   0.615  ...         0.206          0.000003     0.305
#
#         valence   tempo  time_signature  artist_followers  artist_popularity  \
# 730941    0.438  90.029               4           45309.0                 58
# 730942    0.438  90.029               4           93797.0                 53
#
#         year                                              genre
# ...

# %%
data['explicit'].value_counts()
# Out:
# explicit
# 0    693337
# 1     37607
# Name: count, dtype: int64

# %%
data['popularity'].value_counts()
# Out:
# popularity
# 0     65864
# 1     19219
# 2     14696
# 23    14192
# 35    13877
#       ...
# 93        3
# 97        2
# 95        1
# 99        1
# 98        1
# Name: count, Length: 101, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730944 entries, 0 to 730943
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 730944 non-null  object
#  1   name               730944 non-null  object
#  2   popularity         730944 non-null  int64
#  3   duration_ms        730944 non-null  int64
#  4   explicit           730944 non-null  int64
#  5   artists            730944 non-null  object
#  6   id_artists         730944 non-null  object
#  7   release_date       730944 non-null  datetime64[ns]
#  8   danceability       730944 non-null  float64
#  9   energy             730944 non-null  float64
#  10  key                730944 non-null  int64
#  11  loudness           730944 non-null  float64
#  12  mode               730944 non-null  int64
#  13  speechiness        730944 non-null  float64
#  14  acousticness       730944 non-null  float64
# ...

# %%
data['popularity_red'] = data['popularity'].apply(lambda x: int(x/5))

# %%
data.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit          artists              id_artists  \
# 0       126903         0              Uli  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  Fernando Pessoa  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  ...  instrumentalness  liveness  \
# ...

# %%
# !pip install scikit-learn

# %%
data.shape
# Out:
# (730944, 25)

# %%
data = data[data['genre'].apply(len) != 0]

# %%
data.shape
# Out:
# (677666, 25)

# %%
data.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'artist_followers',
#        'artist_popularity', 'year', 'genre', 'popularity_red'],
#       dtype='object')

# %%
data.head()
# Out:
#                        id                                name  popularity  \
# 2  07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                 Lady of the Evening           0
# 5  0BRXJHRNGQ3W4v9frnSfhu                           Ave Maria           0
# 7  0IA0Hju8CAgYfV1hwhidBH                             La Java           0
#
#    duration_ms  explicit          artists              id_artists  \
# 2       181640         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  Ignacio Corsini  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su
# 5       178933         0      Dick Haymes  3BiJGZsyX9sJchTqcSA7Su
# 7       161427         0      Mistinguett  4AxgXfD7ISvJSTObqm4aIE
#
#   release_date  danceability  energy  ...  instrumentalness  liveness  \
# ...

# %%
client_id = ''
client_secret = ''

# %%
import sys

# %%
scope = 'user-library-read'

if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()

# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import spotipy.util as util

# %%
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
token = util.prompt_for_user_token(scope, client_id= client_id, client_secret=client_secret, redirect_uri='http://localhost:8881/')
# Out:
# Opening in existing browser session.

# %%
sp = spotipy.Spotify(auth=token)

# %%
id_name = {}
list_photo = {}
for i in sp.current_user_playlists()['items']:

    id_name[i['name']] = i['uri'].split(':')[2]
    list_photo[i['uri'].split(':')[2]] = i['images'][0]['url']

# %%
id_name
# Out:
# {'GOOD PEOPLE': '0MiCN3tYnFYXldOU4wdePM',
#  'Fuckkkk': '4KJmwasOEu4yFacyK7oReB',
#  "pov: you're in love": '1v6uRVbuIRBQaDBCPu8ItL',
#  'Bolly dance': '4e9BqhxZ032ALC0iZ1rZem',
#  'The Top 500 Heavy Metal Songs Of All Time': '48Yc75hPAZN5mFiaJZrlzV',
#  'a useless piece of shit': '4rDGcz8dK2GVYTKo8LIlEP'}
